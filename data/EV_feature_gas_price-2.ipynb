# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import pandas as pd

# EIA API Key
api_key = "b2eKxsosbujhRxJSXzafNBCiKynhoBqaAGLQlNQY"

# API endpoint following the structure in your screenshot
url = (
    "https://api.eia.gov/v2/petroleum/pri/refmg/data/"
    "?frequency=monthly&data[0]=value"
    "&start=2014-01-01&sort[0][column]=period"
    "&sort[0][direction]=asc&offset=0&length=5000"
    f"&api_key={api_key}"
)

# API request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Get the JSON content
    prices = data.get('response', {}).get('data', [])  # Extract the data

    if prices:
        # Convert the data to a pandas DataFrame
        df_petro2 = pd.json_normalize(prices)
        df_petro2
    else:
        print("No data available.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
df_gas_pa = df_petro2[df_petro2["area-name"] == "USA-PA"]

# %%
# Drop rows where the 'value' column has None or NaN values
df_gas_pa_notna= df_gas_pa.dropna(subset=['value'])

# Display the cleaned DataFrame
df_gas_pa_notna
# Out:
#        period duoarea area-name product       product-name process  \
# 149   2014-01     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 201   2014-01     SPA    USA-PA    EPMR   Regular Gasoline     PWG
# 405   2014-01     SPA    USA-PA    EPMP   Premium Gasoline     PWG
# 630   2014-01     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 1189  2014-02     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 1204  2014-02     SPA    USA-PA    EPMR   Regular Gasoline     PWG
# 1310  2014-02     SPA    USA-PA    EPMP   Premium Gasoline     PWG
# 1427  2014-02     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 1565  2014-03     SPA    USA-PA    EPMR   Regular Gasoline     PWG
# 1617  2014-03     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 1821  2014-03     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 1866  2014-03     SPA    USA-PA    EPMP   Premium Gasoline     PWG
# 2276  2014-04     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 2296  2014-04     SPA    USA-PA    EPMR   Regular Gasoline     PWG
# 2436  2014-04     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 2776  2014-04     SPA    USA-PA    EPMP   Premium Gasoline     PWG
# 2968  2014-05     SPA    USA-PA    EPMP   Premium Gasoline     PWG
# 2989  2014-05     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 3035  2014-05     SPA    USA-PA    EPMR   Regular Gasoline     PWG
# 3111  2014-05     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 3797  2014-06     SPA    USA-PA    EPMP   Premium Gasoline     PWG
# 3967  2014-06     SPA    USA-PA    EPMR   Regular Gasoline     PWG
# 4213  2014-06     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 4365  2014-06     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 4587  2014-07     SPA    USA-PA    EPMM  Midgrade Gasoline     PWG
# 4694  2014-07     SPA    USA-PA    EPM0     Total Gasoline     PWG
# 4714  2014-07     SPA    USA-PA    EPMR   Regular Gasoline     PWG
#
#                                            process-name                series  \
# 149   Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 201   Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
# 405   Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMP_PWG_SPA_DPG
# 630   Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 1189  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 1204  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
# 1310  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMP_PWG_SPA_DPG
# 1427  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 1565  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
# 1617  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 1821  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 1866  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMP_PWG_SPA_DPG
# 2276  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 2296  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
# 2436  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 2776  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMP_PWG_SPA_DPG
# 2968  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMP_PWG_SPA_DPG
# 2989  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 3035  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
# 3111  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 3797  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMP_PWG_SPA_DPG
# 3967  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
# 4213  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 4365  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 4587  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMM_PWG_SPA_DPG
# 4694  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPM0_PWG_SPA_DPG
# 4714  Wholesale/Resale Price by Refiners and Gas Plants  EMA_EPMR_PWG_SPA_DPG
#
#                                      series-description  value  units
# 149   Pennsylvania Gasoline Midgrade Wholesale/Resal...  2.718  $/GAL
# 201   Pennsylvania Regular Gasoline Wholesale/Resale...  2.639  $/GAL
# 405   Pennsylvania Premium Gasoline Wholesale/Resale...  2.873  $/GAL
# 630   Pennsylvania Total Gasoline Wholesale/Resale P...  2.658  $/GAL
# 1189  Pennsylvania Total Gasoline Wholesale/Resale P...  2.746  $/GAL
# 1204  Pennsylvania Regular Gasoline Wholesale/Resale...  2.728  $/GAL
# 1310  Pennsylvania Premium Gasoline Wholesale/Resale...  2.957  $/GAL
# 1427  Pennsylvania Gasoline Midgrade Wholesale/Resal...  2.801  $/GAL
# 1565  Pennsylvania Regular Gasoline Wholesale/Resale...  2.807  $/GAL
# 1617  Pennsylvania Gasoline Midgrade Wholesale/Resal...  2.886  $/GAL
# 1821  Pennsylvania Total Gasoline Wholesale/Resale P...  2.829  $/GAL
# 1866  Pennsylvania Premium Gasoline Wholesale/Resale...  3.057  $/GAL
# 2276  Pennsylvania Total Gasoline Wholesale/Resale P...  2.938  $/GAL
# 2296  Pennsylvania Regular Gasoline Wholesale/Resale...  2.914  $/GAL
# 2436  Pennsylvania Gasoline Midgrade Wholesale/Resal...  3.001  $/GAL
# 2776  Pennsylvania Premium Gasoline Wholesale/Resale...  3.175  $/GAL
# 2968  Pennsylvania Premium Gasoline Wholesale/Resale...  3.173  $/GAL
# 2989  Pennsylvania Gasoline Midgrade Wholesale/Resal...  3.025  $/GAL
# 3035  Pennsylvania Regular Gasoline Wholesale/Resale...  2.924  $/GAL
# 3111  Pennsylvania Total Gasoline Wholesale/Resale P...  2.946  $/GAL
# 3797  Pennsylvania Premium Gasoline Wholesale/Resale...    3.2  $/GAL
# 3967  Pennsylvania Regular Gasoline Wholesale/Resale...  2.943  $/GAL
# 4213  Pennsylvania Total Gasoline Wholesale/Resale P...  2.966  $/GAL
# 4365  Pennsylvania Gasoline Midgrade Wholesale/Resal...  3.042  $/GAL
# 4587  Pennsylvania Gasoline Midgrade Wholesale/Resal...  2.915  $/GAL
# 4694  Pennsylvania Total Gasoline Wholesale/Resale P...  2.836  $/GAL
# 4714  Pennsylvania Regular Gasoline Wholesale/Resale...  2.813  $/GAL

# %%
# Export the cleaned DataFrame to a CSV file
csv_file_path = "/content/drive/MyDrive/Time series/df_gas_pa_notna_2014.csv"
df_gas_pa_notna.to_csv(csv_file_path, index=False)

print(f"Cleaned DataFrame exported to CSV at {csv_file_path}")
# Out:
# Cleaned DataFrame exported to CSV at /content/drive/MyDrive/Time series/df_gas_pa_notna_2014.csv
